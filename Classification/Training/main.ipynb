# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score
from mlxtend.plotting import plot_decision_regions

# %% [markdown]
# # Data

# %%
data = pd.read_csv('Data.csv')
data.head()
# Out:
#    Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0             1000025                5                        1
# 1             1002945                5                        4
# 2             1015425                3                        1
# 3             1016277                6                        8
# 4             1017023                4                        1
#
#    Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                         1                  1                            2
# 1                         4                  5                            7
# 2                         1                  1                            2
# 3                         8                  1                            3
# 4                         1                  3                            2
#
#    Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# ...

# %% [markdown]
# Independent and dependent variable

# %%
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

# %% [markdown]
# Feature Scaling

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# Splitting Training and Testing Dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=0)

# %% [markdown]
# # Training The Model

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logistic = LogisticRegression(random_state=0)
logistic.fit(X_train, y_train)
y_logistic = logistic.predict(X_test)
print('Logistic Accuracy:', accuracy_score(y_test, y_logistic))
ConfusionMatrixDisplay.from_estimator(logistic, X_test, y_test)
plt.show()
# Out:
# Logistic Accuracy: 0.9473684210526315

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5, weights='uniform')
knn.fit(X_train, y_train)
y_knn = knn.predict(X_test)
print('KNN accuracy:', accuracy_score(y_test, y_knn))
ConfusionMatrixDisplay.from_estimator(knn, X_test, y_test)
plt.show()
# Out:
# KNN accuracy: 0.9473684210526315

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC
svm = SVC(kernel='linear', random_state= 0)
svm.fit(X_train, y_train)
y_svm = svm.predict(X_test)
print('SVM Accuracy:',accuracy_score(y_test, y_svm))
ConfusionMatrixDisplay.from_estimator(svm, X_test, y_test)
plt.show()
# Out:
# SVM Accuracy: 0.9415204678362573

# %% [markdown]
# Kernel SVM

# %%
from sklearn.svm import SVC
rbf = SVC(kernel='rbf', random_state= 0)
rbf.fit(X_train, y_train)
y_rbf = rbf.predict(X_test)
print('SVM Accuracy:',accuracy_score(y_test, y_rbf))
ConfusionMatrixDisplay.from_estimator(rbf, X_test, y_test)
plt.show()
# Out:
# SVM Accuracy: 0.9532163742690059

# %% [markdown]
# Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
bayes = GaussianNB()
bayes.fit(X_train, y_train)
y_bayes = bayes.predict(X_test)
print('Bayes Accuracy:',accuracy_score(y_test, y_bayes))
ConfusionMatrixDisplay.from_estimator(bayes, X_test, y_test)
plt.show()
# Out:
# Bayes Accuracy: 0.9415204678362573

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(criterion='entropy', random_state=0)
tree.fit(X_train, y_train)
y_tree = tree.predict(X_test)
print('DecisionTreeClassifier Accuracy:',accuracy_score(y_test, y_tree))
ConfusionMatrixDisplay.from_estimator(tree, X_test, y_test)
plt.show()
# Out:
# DecisionTreeClassifier Accuracy: 0.9590643274853801

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
forest.fit(X_train, y_train)
y_forest = forest.predict(X_test)
print('RandomForest Accuracy:',accuracy_score(y_test, y_forest))
ConfusionMatrixDisplay.from_estimator(forest, X_test, y_test)
plt.show()
# Out:
# RandomForest Accuracy: 0.9298245614035088
